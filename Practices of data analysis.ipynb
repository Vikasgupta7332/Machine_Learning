# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sb

# %% [markdown]
# ### P1

# %%
mydata=pd.read_excel(r"C:\Users\Dell\Desktop\ML-programing\dataset\general-election-2019-main\general-election-2019-main\up_15.xlsx")

# %%
mydata
# Out:
#       ID                 MP Name Nature of membership         Start of Term  \
# 0   1405              Ajit Singh              Elected  Monday, May 18, 2009
# 1   1406          Akhilesh Yadav              Elected  Monday, May 18, 2009
# 2   1417             Annu Tandon              Elected  Monday, May 18, 2009
# 3   1427  Arvind Kumar Chaudhary              Elected  Monday, May 18, 2009
# 4   1431       Ashok Kumar Rawat              Elected  Monday, May 18, 2009
# ..   ...                     ...                  ...                   ...
# 76  1931     Vijay Bahadur Singh              Elected  Monday, May 18, 2009
# 77  1936      Vinay Kumar Pandey              Elected  Monday, May 18, 2009
# 78  1948           Yashvir Singh              Elected  Monday, May 18, 2009
# 79  1950         Yogi Adityanath              Elected  Monday, May 18, 2009
# 80  1951         Zafar Ali Naqvi              Elected  Monday, May 18, 2009
#
# ...

# %%
type(mydata)
# Out:
# pandas.core.frame.DataFrame

# %%
mydata.size
# Out:
# 2268

# %%
mydata.shape
# Out:
# (81, 28)

# %%
len(mydata)# Its print no of record in your database
# Out:
# 81

# %%
mydata.head()
# Out:
#      ID                 MP Name Nature of membership         Start of Term  \
# 0  1405              Ajit Singh              Elected  Monday, May 18, 2009
# 1  1406          Akhilesh Yadav              Elected  Monday, May 18, 2009
# 2  1417             Annu Tandon              Elected  Monday, May 18, 2009
# 3  1427  Arvind Kumar Chaudhary              Elected  Monday, May 18, 2009
# 4  1431       Ashok Kumar Rawat              Elected  Monday, May 18, 2009
#
#                 End of Term  Number of terms Constituency          State  \
# 0                 In office              NaN      Baghpat  Uttar Pradesh
# 1  Sunday, February 5, 2012              NaN      Kannauj  Uttar Pradesh
# 2                 In office              NaN        Unnao  Uttar Pradesh
# 3                 In office              NaN        Basti  Uttar Pradesh
# 4                 In office              NaN      Misrikh  Uttar Pradesh
#
#             Political party  Gender  ... National Debates average  \
# ...

# %%
mydata.tail()
# Out:
#       ID              MP Name Nature of membership         Start of Term  \
# 76  1931  Vijay Bahadur Singh              Elected  Monday, May 18, 2009
# 77  1936   Vinay Kumar Pandey              Elected  Monday, May 18, 2009
# 78  1948        Yashvir Singh              Elected  Monday, May 18, 2009
# 79  1950      Yogi Adityanath              Elected  Monday, May 18, 2009
# 80  1951      Zafar Ali Naqvi              Elected  Monday, May 18, 2009
#
#    End of Term  Number of terms Constituency          State  \
# 76   In office              NaN     Hamirpur  Uttar Pradesh
# 77   In office              NaN    Shrawasti  Uttar Pradesh
# 78   In office              NaN       Nagina  Uttar Pradesh
# 79   In office              NaN    Gorakhpur  Uttar Pradesh
# 80   In office              NaN        Kheri  Uttar Pradesh
#
#              Political party Gender  ... National Debates average  \
# 76       Bahujan Samaj Party   Male  ...                     37.9
# ...

# %%
mydata.sample(4)
# Out:
#       ID              MP Name Nature of membership         Start of Term  \
# 66  1856       Seema Upadhyay              Elected  Monday, May 18, 2009
# 6   1444              Baliram              Elected  Monday, May 18, 2009
# 69  1873  Shriprakash Jaiswal              Elected  Monday, May 18, 2009
# 12  1500      Dhananjay Singh              Elected  Monday, May 18, 2009
#
#    End of Term  Number of terms    Constituency          State  \
# 66   In office              NaN  Fatehpur Sikri  Uttar Pradesh
# 6    In office              NaN         Lalganj  Uttar Pradesh
# 69   In office              NaN          Kanpur  Uttar Pradesh
# 12   In office              NaN         Jaunpur  Uttar Pradesh
#
#              Political party  Gender  ... National Debates average  \
# 66       Bahujan Samaj Party  Female  ...                     37.9
# 6        Bahujan Samaj Party    Male  ...                     37.9
# 69  Indian National Congress    Male  ...                      NaN
# ...

# %%
mydata.describe().T
# Out:
#                                        count         mean           std  \
# ID                                      81.0  1696.345679  1.616976e+02
# Number of terms                          0.0          NaN           NaN
# Age                                     81.0    54.592593  1.203929e+01
# Debates                                 76.0    42.657895  6.052031e+01
# Private Member Bills                    76.0     0.407895  1.515939e+00
# Questions                               76.0   246.736842  2.404362e+02
# Attendance                              76.0     0.793684  1.592804e-01
# National Debates average                76.0    36.735526  4.913511e+00
# National Private Member Bills average   76.0     0.776316  1.018082e-01
# National Questions average              76.0   291.184211  3.732335e+01
# National Attendance average             76.0     0.760000  5.588000e-16
# State's Debates average                 76.0    42.573684  5.601723e+00
# ...

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 28 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   ID                                     81 non-null     int64
#  1   MP Name                                81 non-null     object
#  2   Nature of membership                   81 non-null     object
#  3   Start of Term                          81 non-null     object
#  4   End of Term                            81 non-null     object
#  5   Number of terms                        0 non-null      float64
#  6   Constituency                           81 non-null     object
#  7   State                                  81 non-null     object
#  8   Political party                        81 non-null     object
#  9   Gender                                 81 non-null     object
# ...

# %%
mydata.columns
# Out:
# Index(['ID', 'MP Name', 'Nature of membership', 'Start of Term', 'End of Term',
#        'Number of terms', 'Constituency', 'State', 'Political party', 'Gender',
#        'Educational qualifications', 'Educational qualifications - details',
#        'Age', 'Debates', 'Private Member Bills', 'Questions', 'Attendance',
#        'Notes', 'National Debates average',
#        'National Private Member Bills average', 'National Questions average',
#        'National Attendance average', 'State's Debates average',
#        'State's Private Member Bills average', 'State Questions',
#        'State's Attendance average', 'Unnamed: 26', 'House'],
#       dtype='object')

# %%
mydata["Gender"] =="Male"
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4      True
#       ...
# 76     True
# 77     True
# 78     True
# 79     True
# 80     True
# Name: Gender, Length: 81, dtype: bool

# %%
no_of_males=mydata[mydata["Gender"] == "Male"]

# %%
no_of_males
# Out:
#       ID                 MP Name Nature of membership         Start of Term  \
# 0   1405              Ajit Singh              Elected  Monday, May 18, 2009
# 1   1406          Akhilesh Yadav              Elected  Monday, May 18, 2009
# 3   1427  Arvind Kumar Chaudhary              Elected  Monday, May 18, 2009
# 4   1431       Ashok Kumar Rawat              Elected  Monday, May 18, 2009
# 5   1443         Bal Kumar Patel              Elected  Monday, May 18, 2009
# ..   ...                     ...                  ...                   ...
# 76  1931     Vijay Bahadur Singh              Elected  Monday, May 18, 2009
# 77  1936      Vinay Kumar Pandey              Elected  Monday, May 18, 2009
# 78  1948           Yashvir Singh              Elected  Monday, May 18, 2009
# 79  1950         Yogi Adityanath              Elected  Monday, May 18, 2009
# 80  1951         Zafar Ali Naqvi              Elected  Monday, May 18, 2009
#
# ...

# %%
len(no_of_males)
# Out:
# 68

# %%
no_of_Females=mydata[mydata["Gender"] == "Female"]

# %%
no_of_Females
# Out:
#       ID               MP Name Nature of membership           Start of Term  \
# 2   1417           Annu Tandon              Elected    Monday, May 18, 2009
# 14  1506          Dimple Yadav              Elected  Saturday, June 9, 2012
# 25  1600          Kaisar Jahan              Elected    Monday, May 18, 2009
# 32  1667         Maneka Gandhi              Elected    Monday, May 18, 2009
# 39  1721  P. Jaya Prada Nahata              Elected    Monday, May 18, 2009
# 49  1778    Raj Kumari Chauhan              Elected    Monday, May 18, 2009
# 60  1815           Ratna Singh              Elected    Monday, May 18, 2009
# 65  1850   Sarika Singh Baghel              Elected    Monday, May 18, 2009
# 66  1856        Seema Upadhyay              Elected    Monday, May 18, 2009
# 70  1885          Sonia Gandhi              Elected    Monday, May 18, 2009
# 72  1906         Sushila Saroj              Elected    Monday, May 18, 2009
# ...

# %%
len(no_of_Females)
# Out:
# 13

# %%
plt.figure(figsize=(20,5))
sb.countplot(x="Gender",data=mydata)
plt.show()

# %% [markdown]
# ### P2

# %%
mydata2=pd.read_csv(r"C:\Users\Dell\Desktop\ML-programing\dataset\DataSets-master\DataSets-master\Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv")

# %%
mydata2
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2011     2011           AL         Alabama
# 1           2011     2011           AL         Alabama
# 2           2011     2011           AL         Alabama
# 3           2011     2011           AL         Alabama
# 4           2011     2011           AL         Alabama
# ...          ...      ...          ...             ...
# 53387       2016     2016           VI  Virgin Islands
# 53388       2016     2016           VI  Virgin Islands
# 53389       2016     2016           VI  Virgin Islands
# 53390       2016     2016           VI  Virgin Islands
# 53391       2016     2016           VI  Virgin Islands
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...

# %%
type(mydata2)
# Out:
# pandas.core.frame.DataFrame

# %%
mydata2.size
# Out:
# 1761936

# %%
mydata2.shape
# Out:
# (53392, 33)

# %%
mydata2.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2011     2011           AL      Alabama
# 1       2011     2011           AL      Alabama
# 2       2011     2011           AL      Alabama
# 3       2011     2011           AL      Alabama
# 4       2011     2011           AL      Alabama
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 1  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# ...

# %%
mydata2.tail()
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 53387       2016     2016           VI  Virgin Islands
# 53388       2016     2016           VI  Virgin Islands
# 53389       2016     2016           VI  Virgin Islands
# 53390       2016     2016           VI  Virgin Islands
# 53391       2016     2016           VI  Virgin Islands
#
#                                        Datasource              Class  \
# 53387  Behavioral Risk Factor Surveillance System  Physical Activity
# 53388  Behavioral Risk Factor Surveillance System  Physical Activity
# 53389  Behavioral Risk Factor Surveillance System  Physical Activity
# 53390  Behavioral Risk Factor Surveillance System  Physical Activity
# 53391  Behavioral Risk Factor Surveillance System  Physical Activity
#
#                               Topic  \
# 53387  Physical Activity - Behavior
# 53388  Physical Activity - Behavior
# 53389  Physical Activity - Behavior
# 53390  Physical Activity - Behavior
# ...

# %%
mydata2.sample(3)
# Out:
#        YearStart  YearEnd LocationAbbr LocationDesc  \
# 18286       2011     2011           US     National
# 7521        2011     2011           HI       Hawaii
# 37539       2015     2015           TN    Tennessee
#
#                                        Datasource                    Class  \
# 18286  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 7521   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 37539  Behavioral Risk Factor Surveillance System    Fruits and Vegetables
#
#                                   Topic  \
# 18286           Obesity / Weight Status
# 7521            Obesity / Weight Status
# 37539  Fruits and Vegetables - Behavior
#
#                                                 Question  Data_Value_Unit  \
# 18286  Percent of adults aged 18 years and older who ...              NaN
# 7521   Percent of adults aged 18 years and older who ...              NaN
# ...

# %%
len(mydata2)
# Out:
# 53392
