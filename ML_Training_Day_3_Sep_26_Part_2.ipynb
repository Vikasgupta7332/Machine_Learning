# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sb

# %%
lok = pd.read_csv(r"C:\Users\Dell\Desktop\ML-programing\dataset\general-election-2019-main\general-election-2019-main\LokSabha.csv")

# %%
lok
# Out:
#               STATE     CONSTITUENCY                   NAME  WINNER PARTY  \
# 0         Telangana         ADILABAD         SOYAM BAPU RAO       1   BJP
# 1         Telangana         ADILABAD           Godam Nagesh       0   TRS
# 2         Telangana         ADILABAD          RATHOD RAMESH       0   INC
# 3         Telangana         ADILABAD                   NOTA       0  NOTA
# 4     Uttar Pradesh             AGRA  Satyapal Singh Baghel       1   BJP
# ...             ...              ...                    ...     ...   ...
# 2258    Maharashtra  YAVATMAL-WASHIM     Anil Jayram Rathod       0   IND
# 2259      Telangana        ZAHIRABAD              B.B.PATIL       1   TRS
# 2260      Telangana        ZAHIRABAD        MADAN MOHAN RAO       0   INC
# 2261      Telangana        ZAHIRABAD     BANALA LAXMA REDDY       0   BJP
# 2262      Telangana        ZAHIRABAD                   NOTA       0  NOTA
#
#      SYMBOL GENDER CRIMINAL\nCASES   AGE CATEGORY      EDUCATION  \
# ...

# %%
lok.shape
# Out:
# (2263, 19)

# %%
lok.columns
# Out:
# Index(['STATE', 'CONSTITUENCY', 'NAME', 'WINNER', 'PARTY', 'SYMBOL', 'GENDER',
#        'CRIMINAL\nCASES', 'AGE', 'CATEGORY', 'EDUCATION', 'ASSETS',
#        'LIABILITIES', 'GENERAL\nVOTES', 'POSTAL\nVOTES', 'TOTAL\nVOTES',
#        'OVER TOTAL ELECTORS \nIN CONSTITUENCY',
#        'OVER TOTAL VOTES POLLED \nIN CONSTITUENCY', 'TOTAL ELECTORS'],
#       dtype='object')

# %%
lok["CONSTITUENCY"]
# Out:
# 0              ADILABAD
# 1              ADILABAD
# 2              ADILABAD
# 3              ADILABAD
# 4                  AGRA
#              ...
# 2258    YAVATMAL-WASHIM
# 2259          ZAHIRABAD
# 2260          ZAHIRABAD
# 2261          ZAHIRABAD
# 2262          ZAHIRABAD
# Name: CONSTITUENCY, Length: 2263, dtype: object

# %%
lok["CONSTITUENCY"].value_counts()
# Out:
# AURANGABAD        14
# GAYA (SC)         12
# MAHARAJGANJ        9
# UJIARPUR           9
# ARUKU              8
#                   ..
# BHOPAL             2
# HAVERI             2
# MANDSOUR           2
# JHUNJHUNU          2
# AHMEDABAD EAST     2
# Name: CONSTITUENCY, Length: 539, dtype: int64

# %%
lok[lok["CONSTITUENCY"]=="AURANGABAD"]
# Out:
#            STATE CONSTITUENCY                               NAME  WINNER  \
# 170        Bihar   AURANGABAD                 SUSHIL KUMAR SINGH       1
# 171  Maharashtra   AURANGABAD                 Imtiaz Jaleel Syed       1
# 172        Bihar   AURANGABAD                       NARESH YADAV       1
# 173        Bihar   AURANGABAD                     UPENDRA PRASAD       0
# 174  Maharashtra   AURANGABAD                 Chandrakant Khaire       0
# 175  Maharashtra   AURANGABAD  Harshwardhandada Raibhanji Jadhav       0
# 176  Maharashtra   AURANGABAD          Zambad Subhash Manakchand       0
# 177        Bihar   AURANGABAD              DHIRENDRA KUMAR SINGH       0
# 178        Bihar   AURANGABAD                               NOTA       0
# 179        Bihar   AURANGABAD                DR DHARMENDRA KUMAR       0
# 180        Bihar   AURANGABAD                SANTOSH KUMAR SINHA       0
# 181        Bihar   AURANGABAD                      AVINASH KUMAR       0
# ...

# %%
lok["CONSTITUENCY"].value_counts()[:5]
# Out:
# AURANGABAD     14
# GAYA (SC)      12
# MAHARAJGANJ     9
# UJIARPUR        9
# ARUKU           8
# Name: CONSTITUENCY, dtype: int64

# %%
lok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2263 entries, 0 to 2262
# Data columns (total 19 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   STATE                                     2263 non-null   object
#  1   CONSTITUENCY                              2263 non-null   object
#  2   NAME                                      2263 non-null   object
#  3   WINNER                                    2263 non-null   int64
#  4   PARTY                                     2263 non-null   object
#  5   SYMBOL                                    2018 non-null   object
#  6   GENDER                                    2018 non-null   object
#  7   CRIMINAL
# CASES                            2018 non-null   object
#  8   AGE                                       2018 non-null   float64
#  9   CATEGORY                                  2018 non-null   object
# ...

# %%
lok.rename(columns={"CRIMINAL\nCASES":"Criminal"},inplace=True)

# %%
lok
# Out:
#               STATE     CONSTITUENCY                   NAME  WINNER PARTY  \
# 0         Telangana         ADILABAD         SOYAM BAPU RAO       1   BJP
# 1         Telangana         ADILABAD           Godam Nagesh       0   TRS
# 2         Telangana         ADILABAD          RATHOD RAMESH       0   INC
# 3         Telangana         ADILABAD                   NOTA       0  NOTA
# 4     Uttar Pradesh             AGRA  Satyapal Singh Baghel       1   BJP
# ...             ...              ...                    ...     ...   ...
# 2258    Maharashtra  YAVATMAL-WASHIM     Anil Jayram Rathod       0   IND
# 2259      Telangana        ZAHIRABAD              B.B.PATIL       1   TRS
# 2260      Telangana        ZAHIRABAD        MADAN MOHAN RAO       0   INC
# 2261      Telangana        ZAHIRABAD     BANALA LAXMA REDDY       0   BJP
# 2262      Telangana        ZAHIRABAD                   NOTA       0  NOTA
#
#      SYMBOL GENDER Criminal   AGE CATEGORY      EDUCATION  \
# ...

# %%
lok.corr()
# Out:
#                                              WINNER       AGE  GENERAL\nVOTES  \
# WINNER                                     1.000000  0.110294        0.725678
# AGE                                        0.110294  1.000000        0.208567
# GENERAL\nVOTES                             0.725678  0.208567        1.000000
# POSTAL\nVOTES                              0.520286  0.129360        0.616742
# TOTAL\nVOTES                               0.726125  0.208600        0.999988
# OVER TOTAL ELECTORS \nIN CONSTITUENCY      0.738976  0.207304        0.962219
# OVER TOTAL VOTES POLLED \nIN CONSTITUENCY  0.757303  0.223700        0.962905
# TOTAL ELECTORS                             0.038107  0.021083        0.211092
#
#                                            POSTAL\nVOTES  TOTAL\nVOTES  \
# WINNER                                          0.520286      0.726125
# AGE                                             0.129360      0.208600
# ...

# %%
lok["Criminal"].value_counts()
# Out:
# 0                1242
# 1                 313
# 2                 119
# 3                 104
# 4                  64
# 5                  42
# 6                  26
# Not Available      22
# 7                  18
# 8                  16
# 10                 11
# 9                  11
# 11                  5
# 14                  4
# 12                  4
# 13                  3
# 15                  2
# 40                  1
# 28                  1
# 31                  1
# 22                  1
# 240                 1
# 41                  1
# 16                  1
# 24                  1
# 204                 1
# 18                  1
# 42                  1
# 52                  1
# Name: Criminal, dtype: int64

# %%
lok["Criminal"]=lok["Criminal"].replace(['Not Available'],'0')

# %%
lok["Criminal"].value_counts()
# Out:
# 0      1264
# 1       313
# 2       119
# 3       104
# 4        64
# 5        42
# 6        26
# 7        18
# 8        16
# 10       11
# 9        11
# 11        5
# 14        4
# 12        4
# 13        3
# 15        2
# 40        1
# 22        1
# 28        1
# 31        1
# 240       1
# 41        1
# 16        1
# 24        1
# 204       1
# 18        1
# 42        1
# 52        1
# Name: Criminal, dtype: int64

# %%
lok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2263 entries, 0 to 2262
# Data columns (total 19 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   STATE                                     2263 non-null   object
#  1   CONSTITUENCY                              2263 non-null   object
#  2   NAME                                      2263 non-null   object
#  3   WINNER                                    2263 non-null   int64
#  4   PARTY                                     2263 non-null   object
#  5   SYMBOL                                    2018 non-null   object
#  6   GENDER                                    2018 non-null   object
#  7   Criminal                                  2018 non-null   object
#  8   AGE                                       2018 non-null   float64
#  9   CATEGORY                                  2018 non-null   object
# ...

# %%
lok["Criminal"]=pd.to_numeric(lok["Criminal"],errors="coerce")

# %%
lok["Criminal"].value_counts()
# Out:
# 0.0      1264
# 1.0       313
# 2.0       119
# 3.0       104
# 4.0        64
# 5.0        42
# 6.0        26
# 7.0        18
# 8.0        16
# 9.0        11
# 10.0       11
# 11.0        5
# 14.0        4
# 12.0        4
# 13.0        3
# 15.0        2
# 42.0        1
# 31.0        1
# 28.0        1
# 16.0        1
# 22.0        1
# 18.0        1
# 240.0       1
# 40.0        1
# 204.0       1
# 24.0        1
# 41.0        1
# 52.0        1
# Name: Criminal, dtype: int64

# %%
lok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2263 entries, 0 to 2262
# Data columns (total 19 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   STATE                                     2263 non-null   object
#  1   CONSTITUENCY                              2263 non-null   object
#  2   NAME                                      2263 non-null   object
#  3   WINNER                                    2263 non-null   int64
#  4   PARTY                                     2263 non-null   object
#  5   SYMBOL                                    2018 non-null   object
#  6   GENDER                                    2018 non-null   object
#  7   Criminal                                  2018 non-null   float64
#  8   AGE                                       2018 non-null   float64
#  9   CATEGORY                                  2018 non-null   object
# ...

# %%
lok["Criminal"].isnull().sum()
# Out:
# 245

# %%
plt.figure(figsize=(20,5))
sb.countplot(x="Criminal",data=lok)
plt.show()
