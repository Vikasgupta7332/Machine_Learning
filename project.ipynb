# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### importing libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\Dell\Desktop\ML-programing\dataset\project data\weatherHistory.csv")

# %%
data
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.size
# Out:
# 1157436

# %%
data.shape
# Out:
# (96453, 12)

# %%
data.describe().T
# Out:
#                             count         mean         std        min  \
# Temperature (C)           96453.0    11.932678    9.551546 -21.822222
# Apparent Temperature (C)  96453.0    10.855029   10.696847 -27.716667
# Humidity                  96453.0     0.734899    0.195473   0.000000
# Wind Speed (km/h)         96453.0    10.810640    6.913571   0.000000
# Wind Bearing (degrees)    96453.0   187.509232  107.383428   0.000000
# Visibility (km)           96453.0    10.347325    4.192123   0.000000
# Loud Cover                96453.0     0.000000    0.000000   0.000000
# Pressure (millibars)      96453.0  1003.235956  116.969906   0.000000
#
#                                   25%        50%          75%          max
# Temperature (C)              4.688889    12.0000    18.838889    39.905556
# Apparent Temperature (C)     2.311111    12.0000    18.838889    39.344444
# Humidity                     0.600000     0.7800     0.890000     1.000000
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
data["Precip Type"].value_counts()
# Out:
# rain    85224
# snow    10712
# Name: Precip Type, dtype: int64

# %% [markdown]
# #### Encode { 1: rain, 0:snow)

# %%
data["Precip Type"]=data["Precip Type"].map({"rain":1, "snow":0})

# %%
data.head()
# Out:
#                   Formatted Date        Summary  Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy          1.0         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy          1.0         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy          1.0         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy          1.0         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy          1.0         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# ...

# %% [markdown]
# ### Data Visulization

# %%
sb.pairplot(data)
plt.show()

# %%
data.corr().T
# Out:
#                           Precip Type  Temperature (C)  \
# Precip Type                  1.000000         0.563503
# Temperature (C)              0.563503         1.000000
# Apparent Temperature (C)     0.566058         0.992629
# Humidity                    -0.232622        -0.632255
# Wind Speed (km/h)            0.067771         0.008957
# Wind Bearing (degrees)       0.042142         0.029988
# Visibility (km)              0.316483         0.392847
# Loud Cover                        NaN              NaN
# Pressure (millibars)        -0.009271        -0.005447
#
#                           Apparent Temperature (C)  Humidity  \
# Precip Type                               0.566058 -0.232622
# Temperature (C)                           0.992629 -0.632255
# Apparent Temperature (C)                  1.000000 -0.602571
# Humidity                                 -0.602571  1.000000
# Wind Speed (km/h)                        -0.056650 -0.224951
# ...

# %%
sb.heatmap(data.corr(),annot=True,cmap="coolwarm")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Droping unwanted columns(DATA CLEANING)

# %%
data = data.drop(['Daily Summary','Wind Bearing (degrees)','Summary','Precip Type','Temperature (C)','Loud Cover','Wind Speed (km/h)','Visibility (km)','Pressure (millibars)'],axis=1)

# %%
data.head()
# Out:
#                   Formatted Date  Apparent Temperature (C)  Humidity
# 0  2006-04-01 00:00:00.000 +0200                  7.388889      0.89
# 1  2006-04-01 01:00:00.000 +0200                  7.227778      0.86
# 2  2006-04-01 02:00:00.000 +0200                  9.377778      0.89
# 3  2006-04-01 03:00:00.000 +0200                  5.944444      0.83
# 4  2006-04-01 04:00:00.000 +0200                  6.977778      0.83

# %%
data['Formatted Date'] = pd.to_datetime(data['Formatted Date'],utc=True)
data =data.set_index('Formatted Date')
ds = data[['Apparent Temperature (C)','Humidity']].resample('MS').mean()
ds
# Out:
#                            Apparent Temperature (C)  Humidity
# Formatted Date
# 2005-12-01 00:00:00+00:00                 -4.050000  0.890000
# 2006-01-01 00:00:00+00:00                 -4.173708  0.834610
# 2006-02-01 00:00:00+00:00                 -2.990716  0.843467
# 2006-03-01 00:00:00+00:00                  1.969780  0.778737
# 2006-04-01 00:00:00+00:00                 12.098827  0.728625
# ...                                             ...       ...
# 2016-08-01 00:00:00+00:00                 21.383094  0.674046
# 2016-09-01 00:00:00+00:00                 18.355833  0.688833
# 2016-10-01 00:00:00+00:00                  8.923947  0.799906
# 2016-11-01 00:00:00+00:00                  3.048627  0.848472
# 2016-12-01 00:00:00+00:00                 -2.017272  0.887981
#
# [133 rows x 2 columns]

# %% [markdown]
# ### ploting graph for data analysis

# %%
plt.figure(figsize=(20,5));
plt.plot(ds['Humidity'], label = 'Humidity', color ='blue',linestyle='dashed');
plt.plot(ds['Apparent Temperature (C)'], label = 'Apparent temp.', color  = 'orange');
plt.title('Variation of Apparent temperature v/s Humidity', fontsize = 25);
plt.legend(loc=0, fontsize =14);
plt.xticks(fontsize = 16);
plt.yticks(fontsize=16);

# %% [markdown]
# ### ploting graph for specific month(April)

# %%
april =  ds[ds.index.month==4]
plt.figure(figsize=(15,3))
plt.plot(april.loc['2006-04-01':'2016-04-01','Apparent Temperature (C)'],marker='o', label = 'Apparent Temperature', color ='green',linestyle='-');
plt.plot(april.loc['2006-04-01':'2016-04-01','Humidity'], marker='o',label = 'Humidity', color  = 'orange');
plt.legend(loc='center right', fontsize =15);
plt.xlabel('Month of April',fontsize = 15);
plt.title('Humidity v/s Apparent Temperature', fontsize = 15);
